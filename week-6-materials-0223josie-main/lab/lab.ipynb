# %% [markdown]
# ### Exercise 1
#
# There are four data samples in the "data" folder.  For each one, load it in and try to find a clustering method which is able to identify the labeled clusters in each case; use data driven techniques to evaluate your clustering, and the adjusted_rand_score to determine your accuracy.  In each case, reflect on whether your data-driven evaluations lead you to your best accuracy scores.
